# %%
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import pandas as pd
import tensorflow as tf

import os
import sys
import time

from tensorflow import keras

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()
dir(housing)
print(housing.DESCR)
print("=" * 100)
print(housing.data.shape)
print(housing.target.shape)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297
#
# ====================================================================================================
# (20640, 8)
# (20640,)

# %%
from sklearn.model_selection import train_test_split

# default test_size is 0.25
x_train_all, x_test, y_train_all, y_test = train_test_split(
    housing.data, housing.target, random_state=7
)

x_train, x_valid, y_train, y_valid = train_test_split(
    x_train_all, y_train_all, random_state=11
)

print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (11610, 8) (11610,)
# (3870, 8) (3870,)
# (5160, 8) (5160,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_valid_scaled = scaler.transform(x_valid)
x_test_scaled = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Model

# keras函数式api
input_wide = keras.layers.Input(shape=[5])
input_deep = keras.layers.Input(shape=[6])
hidden1 = keras.layers.Dense(30, activation="relu")(input_deep)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.concatenate([input_wide, hidden2])
output = keras.layers.Dense(1)(concat)
output2 = keras.layers.Dense(1)(hidden2)

model: Model = Model(inputs=[input_wide, input_deep], outputs=[output, output2])

model.compile(loss="mean_squared_error", optimizer="sgd")
callbacks = [
    keras.callbacks.EarlyStopping(patience=5, min_delta=1e-2)
]
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 30)           210         input_4[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 5)]          0
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 30)           930         dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 35)           0           input_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            36          concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            31          dense_4[0][0]
# ==================================================================================================
# Total params: 1,207
# Trainable params: 1,207
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x_train_scaled_wide = x_train_scaled[:, :5]
x_train_scaled_deep = x_train_scaled[:, 2:]

x_valid_scaled_wide = x_valid_scaled[:, :5]
x_valid_scaled_deep = x_valid_scaled[:, 2:]

x_test_scaled_wide = x_test_scaled[:, :5]
x_test_scaled_deep = x_test_scaled[:, 2:]

history = model.fit(
    [x_train_scaled_wide, x_train_scaled_deep],
    [y_train, y_train],
    validation_data=([x_valid_scaled_wide, x_valid_scaled_deep], [y_valid, y_valid]),
    epochs=100,
    callbacks=callbacks
)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 3s 231us/sample - loss: 2.0968 - dense_5_loss: 0.9748 - dense_6_loss: 1.1213 - val_loss: 1.4116 - val_dense_5_loss: 0.6326 - val_dense_6_loss: 0.7788
# Epoch 2/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 1.5367 - dense_5_loss: 0.7319 - dense_6_loss: 0.8046 - val_loss: 1.1686 - val_dense_5_loss: 0.5026 - val_dense_6_loss: 0.6658
# Epoch 3/100
# 11610/11610 [==============================] - 1s 64us/sample - loss: 1.0340 - dense_5_loss: 0.4622 - dense_6_loss: 0.5721 - val_loss: 1.0028 - val_dense_5_loss: 0.4451 - val_dense_6_loss: 0.5576
# Epoch 4/100
# 11610/11610 [==============================] - 1s 58us/sample - loss: 0.9428 - dense_5_loss: 0.4157 - dense_6_loss: 0.5270 - val_loss: 0.9297 - val_dense_5_loss: 0.4122 - val_dense_6_loss: 0.5174
# Epoch 5/100
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.8797 - dense_5_loss: 0.3928 - dense_6_loss: 0.4869 - val_loss: 0.8949 - val_dense_5_loss: 0.3993 - val_dense_6_loss: 0.4955
# Epoch 6/100
# 11610/11610 [==============================] - 1s 59us/sample - loss: 0.8330 - dense_5_loss: 0.3739 - dense_6_loss: 0.4592 - val_loss: 0.8419 - val_dense_5_loss: 0.3807 - val_dense_6_loss: 0.4610
# Epoch 7/100
# 11610/11610 [==============================] - 1s 57us/sample - loss: 0.8151 - dense_5_loss: 0.3709 - dense_6_loss: 0.4441 - val_loss: 0.8373 - val_dense_5_loss: 0.3776 - val_dense_6_loss: 0.4596
# Epoch 8/100
# 11610/11610 [==============================] - 1s 58us/sample - loss: 0.7910 - dense_5_loss: 0.3613 - dense_6_loss: 0.4296 - val_loss: 0.8321 - val_dense_5_loss: 0.3730 - val_dense_6_loss: 0.4591
# Epoch 9/100
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.7688 - dense_5_loss: 0.3504 - dense_6_loss: 0.4182 - val_loss: 0.7745 - val_dense_5_loss: 0.3532 - val_dense_6_loss: 0.4213
# Epoch 10/100
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.7549 - dense_5_loss: 0.3452 - dense_6_loss: 0.4098 - val_loss: 0.7645 - val_dense_5_loss: 0.3489 - val_dense_6_loss: 0.4155
# Epoch 11/100
# 11610/11610 [==============================] - 1s 57us/sample - loss: 0.7475 - dense_5_loss: 0.3429 - dense_6_loss: 0.4047 - val_loss: 0.8031 - val_dense_5_loss: 0.3889 - val_dense_6_loss: 0.4140
# Epoch 12/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.7406 - dense_5_loss: 0.3395 - dense_6_loss: 0.4009 - val_loss: 0.7600 - val_dense_5_loss: 0.3439 - val_dense_6_loss: 0.4161
# Epoch 13/100
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.7332 - dense_5_loss: 0.3353 - dense_6_loss: 0.3977 - val_loss: 0.7740 - val_dense_5_loss: 0.3729 - val_dense_6_loss: 0.4010
# Epoch 14/100
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.7278 - dense_5_loss: 0.3342 - dense_6_loss: 0.3936 - val_loss: 0.7411 - val_dense_5_loss: 0.3404 - val_dense_6_loss: 0.4006
# Epoch 15/100
# 11610/11610 [==============================] - 1s 58us/sample - loss: 0.7226 - dense_5_loss: 0.3317 - dense_6_loss: 0.3906 - val_loss: 0.7296 - val_dense_5_loss: 0.3362 - val_dense_6_loss: 0.3933
# Epoch 16/100
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.7170 - dense_5_loss: 0.3284 - dense_6_loss: 0.3886 - val_loss: 0.7327 - val_dense_5_loss: 0.3367 - val_dense_6_loss: 0.3959
# Epoch 17/100
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.7144 - dense_5_loss: 0.3275 - dense_6_loss: 0.3868 - val_loss: 0.7407 - val_dense_5_loss: 0.3376 - val_dense_6_loss: 0.4031
# Epoch 18/100
# 11610/11610 [==============================] - 1s 57us/sample - loss: 0.7121 - dense_5_loss: 0.3270 - dense_6_loss: 0.3851 - val_loss: 0.7224 - val_dense_5_loss: 0.3325 - val_dense_6_loss: 0.3898
# Epoch 19/100
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.7081 - dense_5_loss: 0.3252 - dense_6_loss: 0.3828 - val_loss: 0.7294 - val_dense_5_loss: 0.3459 - val_dense_6_loss: 0.3835
# Epoch 20/100
# 11610/11610 [==============================] - 1s 59us/sample - loss: 0.7065 - dense_5_loss: 0.3247 - dense_6_loss: 0.3816 - val_loss: 0.7255 - val_dense_5_loss: 0.3348 - val_dense_6_loss: 0.3907

# %%
def plot_learning_curve(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
#     plt.gca().set_ylim(0, 1)
    plt.show()

plot_learning_curve(history)

# %%
model.evaluate([x_test_scaled_wide, x_test_scaled_deep], [y_test, y_test])
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.7335130105647005, 0.34221473, 0.3943107]
